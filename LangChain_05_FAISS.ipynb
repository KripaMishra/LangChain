# %% [markdown]
# <a href="https://colab.research.google.com/github/KripaMishra/LangChain/blob/main/LangChain_05_FAISS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain
# !pip install pypdf
# !pip install sentence-transformers==2.2.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.8/812.8 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 21.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.6/274.6 kB 21.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 17.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.1/286.1 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install openai
# !pip install tiktoken
# !pip install faiss-cpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.9/262.9 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 13.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 40.2 MB/s eta 0:00:00
# ...

# %%
# !mkdir pdfs

# %%
from langchain.document_loaders import PyPDFDirectoryLoader

# %%
loader=PyPDFDirectoryLoader("pdfs")
data=loader.load()

# %%
data
# Out:
# [Document(page_content='IndicNLG Benchmark: Multilingual Datasets for Diverse NLG Tasks\nin Indic Languages\nAman Kumar1∗Himani Shrotriya2∗Prachi Sahu3∗Raj Dabre4\nRatish Puduppully5Anoop Kunchukuttan6Amogh Mishra7\nMitesh M. Khapra8Pratyush Kumar9\nIIT Madras1,2,3,6,8,9Columbia University7\nNational Institute of Information and Communications Technology4\nMicrosoft6,9University of Edinburgh5AI4Bharat6,8,9\n1cs20m010@smail.iitm.ac.in2cs20m024@smail.iitm.ac.in\n3cs20m047@smail.iitm.ac.in4raj.dabre@nict.go.jp\n5r.puduppully@sms.ed.ac.uk6ankunchu@microsoft.com\n7amogh.mishra@columbia.edu8miteshk@cse.iitm.ac.in\n9pratykumar@microsoft.com\nAbstract\nNatural Language Generation (NLG) for non-\nEnglish languages is hampered by the scarcity\nof datasets in these languages. In this pa-\nper, we present the IndicNLG Benchmark, a\ncollection of datasets for benchmarking NLG\nfor 11 Indic languages. We focus on ﬁve di-\nverse tasks, namely, biography generation us-\ning Wikipedia infoboxes, news
# ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=20)
text_chunks = text_splitter.split_documents(data)

# %%
text_chunks[3]
# Out:
# Document(page_content='to modest-resource languages as they involve\nsimple steps such as scraping news articles and\nWikipedia infoboxes, light cleaning, and pivot-\ning through machine translation data. To the\nbest of our knowledge, the IndicNLG Bench-\nmark is the ﬁrst NLG benchmark for Indic\nlanguages and the most diverse multilingual\nNLG dataset, with approximately 8M exam-\nples across 5 tasks and 11 languages. The\ndatasets and models are publicly available1.\n1 Introduction', metadata={'source': 'pdfs/rp.pdf', 'page': 0})

# %%
from langchain.vectorstores import FAISS

# %%
from langchain.embeddings import HuggingFaceEmbeddings

# %%
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# .gitattributes:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# ...

# %%
vectorstore=FAISS.from_documents(text_chunks, embeddings)

# %%
query = "which is the first NLG benchmark?"

# %%
query
# Out:
# 'which is the first NLG benchmark?'

# %%
docs=vectorstore.similarity_search(query, k=3)

# %%
docs
# Out:
# [Document(page_content='benchmarking for NLG using pre-trained models\nand multilingualism.\n2.1 NLG Benchmarks\nGehrmann et al. (2021 ) create a benchmark, GEM,\nfor NLG tasks such as extreme summarization\n(Hasan et al. ,2021 ;Scialom et al. ,2020 ;Narayan\net al. ,2018 ), data-to-text generation ( Gardent\net al. ,2017 ;Parikh et al. ,2020 ;Nan et al. ,2021 ;\nDušek et al. ,2020 ), and cross lingual summariza-\ntion ( Ladhak et al. ,2020 ). In addition, they aim\nto establish baseline models along with automatic', metadata={'source': 'pdfs/rp.pdf', 'page': 1}),
# ...

# %%
len(docs)
# Out:
# 3

# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

# %%
from langchain.llms import OpenAI
llm=OpenAI(openai_api_key=OPENAI_API_KEY)

# %%
from langchain.chains import RetrievalQA

# %%
qa = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=vectorstore.as_retriever())

# %%
query = "which is the first NLG benchmark?"

# %%
print(qa.run(query))
# Out:
# The first NLG benchmark mentioned in the context is GEM, proposed by Gehrmann et al. in 2021.
